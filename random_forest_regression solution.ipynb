# %%
## Import the important Libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read the dataset

# df = pd.read_csv(r'C:\Mahesh\Datasets\diabetes.csv')

df = pd.read_csv('boston.csv')

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
# check the null values

df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
# basic stats of data

df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df.MEDV.unique()
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 13.6, 19.6, 15.2, 14.5,
#        15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 13.2, 13.1, 13.5, 20. ,
#        24.7, 30.8, 34.9, 26.6, 25.3, 21.2, 19.3, 14.4, 19.4, 19.7, 20.5,
#        25. , 23.4, 35.4, 31.6, 23.3, 18.7, 16. , 22.2, 33. , 23.5, 22. ,
#        17.4, 20.9, 24.2, 22.8, 24.1, 21.4, 20.8, 20.3, 28. , 23.9, 24.8,
#        22.5, 23.6, 22.6, 20.6, 28.4, 38.7, 43.8, 33.2, 27.5, 26.5, 18.6,
#        20.1, 19.5, 19.8, 18.8, 18.5, 18.3, 19.2, 17.3, 15.7, 16.2, 18. ,
#        14.3, 23. , 18.1, 17.1, 13.3, 17.8, 14. , 13.4, 11.8, 13.8, 14.6,
#        15.4, 21.5, 15.3, 17. , 41.3, 24.3, 27. , 50. , 22.7, 23.8, 22.3,
#        19.1, 29.4, 23.2, 24.6, 29.9, 37.2, 39.8, 37.9, 32.5, 26.4, 29.6,
#        32. , 29.8, 37. , 30.5, 36.4, 31.1, 29.1, 33.3, 30.3, 34.6, 32.9,
#        42.3, 48.5, 24.4, 22.4, 28.1, 23.7, 26.7, 30.1, 44.8, 37.6, 46.7,
# ...

# %%
# dependent and independent features

x = df.drop('MEDV',axis=1) # independent features
y = df.MEDV # dependent feature

# %%
x
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, Length: 506, dtype: float64

# %%
# train test split

from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=42)

# %%
x_train
# Out:
#          CRIM    ZN  INDUS  CHAS     NOX     RM   AGE     DIS  RAD    TAX  \
# 182   0.09103   0.0   2.46     0  0.4880  7.155  92.2  2.7006    3  193.0
# 155   3.53501   0.0  19.58     1  0.8710  6.152  82.6  1.7455    5  403.0
# 280   0.03578  20.0   3.33     0  0.4429  7.820  64.5  4.6947    5  216.0
# 126   0.38735   0.0  25.65     0  0.5810  5.613  95.6  1.7572    2  188.0
# 329   0.06724   0.0   3.24     0  0.4600  6.333  17.2  5.2146    4  430.0
# ..        ...   ...    ...   ...     ...    ...   ...     ...  ...    ...
# 106   0.17120   0.0   8.56     0  0.5200  5.836  91.9  2.2110    5  384.0
# 270   0.29916  20.0   6.96     0  0.4640  5.856  42.1  4.4290    3  223.0
# 348   0.01501  80.0   2.01     0  0.4350  6.635  29.7  8.3440    4  280.0
# 435  11.16040   0.0  18.10     0  0.7400  6.629  94.6  2.1247   24  666.0
# 102   0.22876   0.0   8.56     0  0.5200  6.405  85.4  2.7147    5  384.0
#
#      PTRATIO       B  LSTAT
# 182     17.8  394.12   4.82
# ...

# %%
y_train
# Out:
# 182    37.9
# 155    15.6
# 280    45.4
# 126    15.7
# 329    22.6
#        ...
# 106    19.5
# 270    21.1
# 348    24.5
# 435    13.4
# 102    18.6
# Name: MEDV, Length: 379, dtype: float64

# %%
# model selection

from sklearn.ensemble import RandomForestRegressor

# %%
# initialize

rfg = RandomForestRegressor()

# train
rfg.fit(x_train,y_train)

# y predict

y_pred = rfg.predict(x_test)

# %%
# Accuracy of Random forest 

# Model evaluation

from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
mse = mean_squared_error(y_test,y_pred)
print(f'Mean Square Error is : {mse}')
# Out:
# Mean Square Error is : 9.680218960629922

# %%
y_test
# Out:
# 173    23.6
# 274    32.4
# 491    13.6
# 72     22.8
# 452    16.1
#        ...
# 418     8.8
# 117    19.2
# 42     25.3
# 322    20.4
# 347    23.1
# Name: MEDV, Length: 127, dtype: float64

# %%
y_pred
# Out:
# array([22.669, 30.054, 16.827, 23.56 , 16.947, 21.367, 19.402, 15.877,
#        21.192, 20.754, 20.816, 19.878,  8.4  , 21.46 , 19.303, 25.397,
#        18.754,  8.128, 45.023, 15.046, 24.816, 23.916, 14.733, 22.692,
#        15.101, 15.192, 21.523, 14.101, 19.368, 20.991, 19.925, 23.404,
#        29.055, 19.901, 14.94 , 16.058, 34.749, 19.201, 20.725, 24.227,
#        20.53 , 30.228, 45.394, 19.331, 22.215, 13.603, 15.31 , 24.384,
#        18.305, 28.81 , 21.178, 33.501, 16.992, 26.023, 45.639, 22.173,
#        15.669, 32.757, 21.972, 20.888, 25.425, 34.32 , 28.767, 19.285,
#        27.437, 17.387, 13.392, 23.073, 28.18 , 15.986, 20.306, 27.801,
#        10.44 , 21.191, 22.212,  7.053, 20.218, 45.135, 10.992, 12.885,
#        21.637, 11.585, 19.522,  8.97 , 20.374, 26.822, 14.849, 23.439,
#        23.846, 17.82 , 21.817,  7.71 , 19.412, 19.228, 23.795, 19.997,
#        38.434, 11.458, 12.747, 12.14 , 20.331, 23.54 , 13.379, 20.021,
# ...

# %%
rmse = np.sqrt(mse)
print(f'Root Mean square error is : {rmse}')
# Out:
# Root Mean square error is : 3.111305025327784

# %%
# R-Square 

r2 = r2_score(y_test,y_pred)
print(f'R-Square value is : {r2}')
# Out:
# R-Square value is : 0.8617647606987999

# %%
# Hyperparameter tuning 

from sklearn.model_selection import RandomizedSearchCV

# %%
param = {
    'n_estimators' : [50,100,150,200,300],
    'criterion' : ['squared_error','absolute_error','friedman_mse', 'poisson'],
    'max_depth' : [5,10,12,15,None],
    'min_samples_split' : np.arange(2,10)
}

# %%
rf_rscv = RandomizedSearchCV(rfg,param_distributions=param,cv=10,n_jobs=2,scoring='accuracy')

# %%
rf_rscv.fit(x_train,y_train)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1102: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# RandomizedSearchCV(cv=10, estimator=RandomForestRegressor(), n_jobs=2,
#                    param_distributions={'criterion': ['squared_error',
#                                                       'absolute_error',
#                                                       'friedman_mse',
#                                                       'poisson'],
#                                         'max_depth': [5, 10, 12, 15, None],
#                                         'min_samples_split': array([2, 3, 4, 5, 6, 7, 8, 9]),
#                                         'n_estimators': [50, 100, 150, 200,
#                                                          300]},
#                    scoring='accuracy')

# %%
rf_rscv.best_params_
# Out:
# {'n_estimators': 200,
#  'min_samples_split': 6,
#  'max_depth': 10,
#  'criterion': 'absolute_error'}

# %%
rfg_rscv = RandomForestRegressor(n_estimators=200,min_samples_split=6,max_depth=10,criterion='absolute_error')

# %%
rfg_rscv.fit(x_train,y_train)
# Out:
# RandomForestRegressor(criterion='absolute_error', max_depth=10,
#                       min_samples_split=6, n_estimators=200)

# %%
y_pred_rf = rfg_rscv.predict(x_test)

# %%
# Accuracy of Random forest 

# Model evaluation

from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
mse = mean_squared_error(y_test,y_pred_rf)
print(f'Mean Square Error is : {mse}')
# Out:
# Mean Square Error is : 9.120862926673228

# %%
rmse = np.sqrt(mse)
print(f'Root Mean square error is : {rmse}')
# Out:
# Root Mean square error is : 3.020076642516416

# %%
# R-Square 

r2 = r2_score(y_test,y_pred_rf)
print(f'R-Square value is : {r2}')
# Out:
# R-Square value is : 0.8697524638202944
